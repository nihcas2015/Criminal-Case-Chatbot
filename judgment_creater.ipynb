# %%
import os
import google.generativeai as genai

# ========== USER CONFIG ==========
GEMINI_API_KEY = "AIzaSyDzPdBs700AMVBAMKotXYoRmuKVJe9SkAo"
RAW_FOLDER = "crime_cases"        # Folder containing full-text judgments
SUMMARY_FOLDER = "summary"  # Folder for summarized judgments
MODEL_NAME = "gemini-2.5-flash-lite-preview-06-17"     # Fast, free-tier friendly model
# =================================

# Configure Gemini
genai.configure(api_key=GEMINI_API_KEY)
model = genai.GenerativeModel(MODEL_NAME)

# 1. Get list of already summarized files (exclude .txt extension for comparison)
summarized_files = {os.path.splitext(f)[0] for f in os.listdir(SUMMARY_FOLDER) if f.endswith(".txt")}

# 2. Process raw judgments excluding already summarized ones
for raw_file in os.listdir(RAW_FOLDER):
    if not raw_file.endswith(".txt"):
        continue
    
    file_name = os.path.splitext(raw_file)[0]
    if file_name in summarized_files:
        print(f"Skipping already summarized file: {raw_file}")
        continue
    
    # 3. Read raw judgment text
    raw_path = os.path.join(RAW_FOLDER, raw_file)
    with open(raw_path, "r", encoding="utf-8") as f:
        judgment_text = f.read()
    
    # 4. Prepare summarization prompt
    prompt = f"""
    Summarize the following judgment into clear sections:
    1. Case Facts
    2. Issues
    3. Arguments/Reasoning
    4. Decision/Holding
    
    Keep it short, structured, and clear.
    Judgment Text:
    {judgment_text}
    """
    
    # 5. Generate summary using Gemini
    try:
        response = model.generate_content(prompt)
        summary_text = response.text
    except Exception as e:
        print(f"Error summarizing {raw_file}: {e}")
        continue
    
    # 6. Save summarized judgment
    summary_path = os.path.join(SUMMARY_FOLDER, f"{file_name}.txt")
    with open(summary_path, "w", encoding="utf-8") as f:
        f.write(summary_text)
    
    print(f"Summarized file saved: {summary_path}")

print("Processing complete!")
# Out:
# Skipping already summarized file: 1003.txt
# Skipping already summarized file: 1004.txt
# Skipping already summarized file: 101.txt
# Skipping already summarized file: 1012.txt
# Skipping already summarized file: 1062.txt
# Skipping already summarized file: 1069.txt
# Skipping already summarized file: 1075.txt
# Skipping already summarized file: 1079.txt
# Skipping already summarized file: 1103.txt
# Skipping already summarized file: 1105.txt
# Skipping already summarized file: 1112.txt
# Skipping already summarized file: 1115.txt
# Skipping already summarized file: 1127.txt
# Skipping already summarized file: 1137.txt
# Skipping already summarized file: 1138.txt
# Skipping already summarized file: 116.txt
# Skipping already summarized file: 1178.txt
# Skipping already summarized file: 1179.txt
# Skipping already summarized file: 1190.txt
# Skipping already summarized file: 1202.txt
# Skipping already summarized file: 1210.txt
# Skipping already summarized file: 1215.txt
# Skipping already summarized file: 1222.txt
# Skipping already summarized file: 1236.txt
# Skipping already summarized file: 1239.txt
# Skipping already summarized file: 1243.txt
# Skipping already summarized file: 1245.txt
# Skipping already summarized file: 1246.txt
# Skipping already summarized file: 1257.txt
# Skipping already summarized file: 1258.txt
# Skipping already summarized file: 126.txt
# Skipping already summarized file: 1268.txt
# Skipping already summarized file: 1269.txt
# Skipping already summarized file: 1284.txt
# Skipping already summarized file: 1289.txt
# Skipping already summarized file: 1298.txt
# Skipping already summarized file: 1309.txt
# Skipping already summarized file: 1315.txt
# Skipping already summarized file: 1316.txt
# Skipping already summarized file: 2879.txt
# Summarized file saved: summary\2881.txt
# Summarized file saved: summary\2886.txt
# Skipping already summarized file: 2896.txt
# Summarized file saved: summary\2898.txt
# Summarized file saved: summary\2900.txt
# Summarized file saved: summary\2901.txt
# Summarized file saved: summary\2917.txt
# Skipping already summarized file: 2918.txt
# Skipping already summarized file: 2923.txt
# Skipping already summarized file: 2925.txt
# Skipping already summarized file: 2930.txt
# Skipping already summarized file: 2938.txt
# Skipping already summarized file: 294.txt
# Skipping already summarized file: 2942.txt
# Skipping already summarized file: 2947.txt
# Skipping already summarized file: 2948.txt
# Skipping already summarized file: 2949.txt
# Skipping already summarized file: 2950.txt
# Skipping already summarized file: 2963.txt
# Skipping already summarized file: 297.txt
# Skipping already summarized file: 2988.txt
# Summarized file saved: summary\30.txt
# Summarized file saved: summary\3025.txt
# Summarized file saved: summary\3029.txt
# Summarized file saved: summary\3030.txt
# Error summarizing 3045.txt: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15
# Please retry in 53.624608003s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 53
# }
# ]
# Error summarizing 305.txt: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15
# Please retry in 53.313600621s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 53
# }
# ]
# Error summarizing 3057.txt: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15
# Please retry in 53.045220229s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 53
# }
# ]
# Error summarizing 3059.txt: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15
# Please retry in 52.776751928s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 52
# }
# ]
# Error summarizing 3065.txt: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15
# Please retry in 52.509951487s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 52
# }
# ]
# Error summarizing 3069.txt: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15
# Please retry in 52.211048872s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 52
# }
# ]
# Summarized file saved: summary\3079.txt
# Error summarizing 308.txt: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15
# Please retry in 48.929315663s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 48
# }
# ]
# Error summarizing 3080.txt: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15
# Please retry in 48.707671739s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 48
# }
# ]
# Error summarizing 3085.txt: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15
# Please retry in 48.45350539s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 48
# }
# ]
# Error summarizing 3094.txt: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15
# Please retry in 48.243726937s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 48
# }
# ]
# Error summarizing 3099.txt: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15
# Please retry in 47.993773998s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 47
# }
# ]
# Error summarizing 3103.txt: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15
# Please retry in 47.762480706s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 47
# }
# ]
# Error summarizing 3104.txt: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15
# Please retry in 47.483042906s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 47
# }
# ]
# Error summarizing 3116.txt: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15
# Please retry in 47.230470174s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 47
# }
# ]
# Error summarizing 312.txt: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15
# Please retry in 46.917739152s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 46
# }
# ]
# Summarized file saved: summary\3124.txt
# Error summarizing 3126.txt: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15
# Please retry in 43.732342768s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 43
# }
# ]
# Error summarizing 3137.txt: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15
# Please retry in 43.458089191s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 43
# }
# ]
# Error summarizing 314.txt: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15
# Please retry in 43.210029684s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 43
# }
# ]
# Error summarizing 3141.txt: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15
# Please retry in 42.86517508s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 42
# }
# ]
# Summarized file saved: summary\315.txt
# Summarized file saved: summary\3160.txt
# Summarized file saved: summary\3165.txt
# Summarized file saved: summary\3167.txt
# Summarized file saved: summary\3168.txt
# Summarized file saved: summary\3170.txt
# Summarized file saved: summary\3171.txt
# Summarized file saved: summary\3174.txt
# Summarized file saved: summary\3179.txt
# Summarized file saved: summary\3181.txt
# Summarized file saved: summary\3183.txt
# Summarized file saved: summary\3188.txt
# Summarized file saved: summary\3190.txt
# Summarized file saved: summary\3194.txt
# Summarized file saved: summary\320.txt
# Error summarizing 3200.txt: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15
# Please retry in 50.553081885s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 50
# }
# ]
# Summarized file saved: summary\3202.txt
# Error summarizing 3207.txt: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15
# Please retry in 47.601795811s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 47
# }
# ]
# Error summarizing 3218.txt: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15
# Please retry in 47.241495301s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 47
# }
# ]
# Error summarizing 3221.txt: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15
# Please retry in 46.881783754s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 46
# }
# ]
# Error summarizing 3225.txt: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15
# Please retry in 46.531522538s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 46
# }
# ]
# Error summarizing 3236.txt: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15
# Please retry in 46.31795106s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 46
# }
# ]
# Skipping already summarized file: 3238.txt
# Skipping already summarized file: 3241.txt
# Skipping already summarized file: 3245.txt
# Skipping already summarized file: 3247.txt
# Skipping already summarized file: 3252.txt
# Skipping already summarized file: 3280.txt
# Skipping already summarized file: 3282.txt
# Skipping already summarized file: 3283.txt
# Skipping already summarized file: 3291.txt
# Skipping already summarized file: 3299.txt
# Skipping already summarized file: 3304.txt
# Skipping already summarized file: 3305.txt
# Skipping already summarized file: 3306.txt
# Skipping already summarized file: 3317.txt
# Skipping already summarized file: 3318.txt
# Skipping already summarized file: 3319.txt
# Error summarizing 3347.txt: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15
# Please retry in 45.985912449s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 45
# }
# ]
# Error summarizing 3348.txt: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15
# Please retry in 45.670742976s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 45
# }
# ]
# Error summarizing 3350.txt: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15
# Please retry in 45.423719623s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 45
# }
# ]
# Error summarizing 3351.txt: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15
# Please retry in 45.226089412s. [violations {
# ...
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 44
# }
# ]
# Error summarizing 6939.txt: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15
# Please retry in 44.107124438s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 44
# }
# ]
# Error summarizing 6944.txt: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15
# Please retry in 43.912952813s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 43
# }
# ]
# Error summarizing 6955.txt: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15
# Please retry in 43.724692778s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 43
# }
# ]
# Error summarizing 6961.txt: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15
# Please retry in 43.516937623s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 43
# }
# ]
# Error summarizing 6964.txt: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15
# Please retry in 43.307346207s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 43
# }
# ]
# Error summarizing 6965.txt: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15
# Please retry in 43.107544996s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 43
# }
# ]
# Error summarizing 6979.txt: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15
# Please retry in 42.896928173s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 42
# }
# ]
# Skipping already summarized file: 6992.txt
# Skipping already summarized file: 7.txt
# Skipping already summarized file: 7003.txt
# Skipping already summarized file: 7005.txt
# Skipping already summarized file: 7015.txt
# Skipping already summarized file: 7017.txt
# Skipping already summarized file: 7022.txt
# Skipping already summarized file: 7026.txt
# Skipping already summarized file: 7030.txt
# Skipping already summarized file: 7031.txt
# Skipping already summarized file: 7035.txt
# Skipping already summarized file: 7044.txt
# Skipping already summarized file: 7045.txt
# Skipping already summarized file: 7048.txt
# Skipping already summarized file: 7050.txt
# Skipping already summarized file: 7057.txt
# Skipping already summarized file: 7065.txt
# Skipping already summarized file: 7074.txt
# Skipping already summarized file: 7090.txt
# Skipping already summarized file: 7093.txt
# Skipping already summarized file: 7094.txt
# Skipping already summarized file: 7097.txt
# Skipping already summarized file: 7098.txt
# Skipping already summarized file: 7101.txt
# Skipping already summarized file: 7112.txt
# Skipping already summarized file: 7114.txt
# Skipping already summarized file: 7116.txt
# Skipping already summarized file: 715.txt
# Skipping already summarized file: 716.txt
# Skipping already summarized file: 72.txt
# Skipping already summarized file: 726.txt
# Skipping already summarized file: 731.txt
# Skipping already summarized file: 735.txt
# Skipping already summarized file: 74.txt
# Skipping already summarized file: 746.txt
# Error summarizing 750.txt: 500 An internal error has occurred. Please retry or report in https://developers.generativeai.google/guide/troubleshooting
# Error summarizing 762.txt: 500 An internal error has occurred. Please retry or report in https://developers.generativeai.google/guide/troubleshooting
# Error summarizing 768.txt: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15
# Please retry in 41.848825965s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 41
# }
# ]
# Error summarizing 773.txt: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15
# Please retry in 41.628137462s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 41
# }
# ]
# Error summarizing 775.txt: 500 An internal error has occurred. Please retry or report in https://developers.generativeai.google/guide/troubleshooting
# Error summarizing 779.txt: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15
# Please retry in 41.019911165s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 41
# }
# ]
# Error summarizing 78.txt: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15
# Please retry in 40.816747471s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 40
# }
# ]
# Error summarizing 782.txt: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15
# Please retry in 40.588410343s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 40
# }
# ]
# Error summarizing 783.txt: 500 An internal error has occurred. Please retry or report in https://developers.generativeai.google/guide/troubleshooting
# Error summarizing 788.txt: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15
# Please retry in 39.978700558s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 39
# }
# ]
# Error summarizing 789.txt: 500 An internal error has occurred. Please retry or report in https://developers.generativeai.google/guide/troubleshooting
# Error summarizing 79.txt: 500 An internal error has occurred. Please retry or report in https://developers.generativeai.google/guide/troubleshooting
# Error summarizing 792.txt: 500 An internal error has occurred. Please retry or report in https://developers.generativeai.google/guide/troubleshooting
# Error summarizing 793.txt: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15
# Please retry in 38.409532912s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 38
# }
# ]
# Error summarizing 799.txt: 500 An internal error has occurred. Please retry or report in https://developers.generativeai.google/guide/troubleshooting
# Skipping already summarized file: 802.txt
# Skipping already summarized file: 806.txt
# Skipping already summarized file: 81.txt
# Skipping already summarized file: 810.txt
# Skipping already summarized file: 813.txt
# Skipping already summarized file: 817.txt
# Skipping already summarized file: 828.txt
# Skipping already summarized file: 83.txt
# Skipping already summarized file: 834.txt
# Skipping already summarized file: 843.txt
# Skipping already summarized file: 844.txt
# Skipping already summarized file: 849.txt
# Skipping already summarized file: 850.txt
# Skipping already summarized file: 855.txt
# Skipping already summarized file: 86.txt
# Skipping already summarized file: 864.txt
# Skipping already summarized file: 866.txt
# Skipping already summarized file: 885.txt
# Skipping already summarized file: 887.txt
# Skipping already summarized file: 892.txt
# Skipping already summarized file: 939.txt
# Skipping already summarized file: 96.txt
# Skipping already summarized file: 966.txt
# Skipping already summarized file: 967.txt
# Skipping already summarized file: 97.txt
# Skipping already summarized file: 972.txt
# Skipping already summarized file: 978.txt
# Skipping already summarized file: 99.txt
# Skipping already summarized file: 992.txt
# Processing complete!

# %%
models = genai.list_models()

# Print model names and types
for model in models:
    print(f"Name: {model.name} | Supported Generation: {model.supported_generation_methods}")
# Out:
# Name: models/embedding-gecko-001 | Supported Generation: ['embedText', 'countTextTokens']
# Name: models/gemini-2.5-pro-preview-03-25 | Supported Generation: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# Name: models/gemini-2.5-flash-preview-05-20 | Supported Generation: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# Name: models/gemini-2.5-flash | Supported Generation: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# Name: models/gemini-2.5-flash-lite-preview-06-17 | Supported Generation: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# Name: models/gemini-2.5-pro-preview-05-06 | Supported Generation: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# Name: models/gemini-2.5-pro-preview-06-05 | Supported Generation: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# Name: models/gemini-2.5-pro | Supported Generation: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# Name: models/gemini-2.0-flash-exp | Supported Generation: ['generateContent', 'countTokens', 'bidiGenerateContent']
# Name: models/gemini-2.0-flash | Supported Generation: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# Name: models/gemini-2.0-flash-001 | Supported Generation: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# Name: models/gemini-2.0-flash-exp-image-generation | Supported Generation: ['generateContent', 'countTokens', 'bidiGenerateContent']
# Name: models/gemini-2.0-flash-lite-001 | Supported Generation: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# Name: models/gemini-2.0-flash-lite | Supported Generation: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# Name: models/gemini-2.0-flash-preview-image-generation | Supported Generation: ['generateContent', 'countTokens', 'batchGenerateContent']
# Name: models/gemini-2.0-flash-lite-preview-02-05 | Supported Generation: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# Name: models/gemini-2.0-flash-lite-preview | Supported Generation: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# Name: models/gemini-2.0-pro-exp | Supported Generation: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# Name: models/gemini-2.0-pro-exp-02-05 | Supported Generation: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# Name: models/gemini-exp-1206 | Supported Generation: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# Name: models/gemini-2.0-flash-thinking-exp-01-21 | Supported Generation: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# Name: models/gemini-2.0-flash-thinking-exp | Supported Generation: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# Name: models/gemini-2.0-flash-thinking-exp-1219 | Supported Generation: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# Name: models/gemini-2.5-flash-preview-tts | Supported Generation: ['countTokens', 'generateContent']
# Name: models/gemini-2.5-pro-preview-tts | Supported Generation: ['countTokens', 'generateContent']
# Name: models/learnlm-2.0-flash-experimental | Supported Generation: ['generateContent', 'countTokens']
# Name: models/gemma-3-1b-it | Supported Generation: ['generateContent', 'countTokens']
# Name: models/gemma-3-4b-it | Supported Generation: ['generateContent', 'countTokens']
# Name: models/gemma-3-12b-it | Supported Generation: ['generateContent', 'countTokens']
# Name: models/gemma-3-27b-it | Supported Generation: ['generateContent', 'countTokens']
# Name: models/gemma-3n-e4b-it | Supported Generation: ['generateContent', 'countTokens']
# Name: models/gemma-3n-e2b-it | Supported Generation: ['generateContent', 'countTokens']
# Name: models/gemini-flash-latest | Supported Generation: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# Name: models/gemini-flash-lite-latest | Supported Generation: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# Name: models/gemini-pro-latest | Supported Generation: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# Name: models/gemini-2.5-flash-lite | Supported Generation: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# Name: models/gemini-2.5-flash-image-preview | Supported Generation: ['generateContent', 'countTokens']
# Name: models/gemini-2.5-flash-preview-09-2025 | Supported Generation: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# Name: models/gemini-2.5-flash-lite-preview-09-2025 | Supported Generation: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# Name: models/gemini-robotics-er-1.5-preview | Supported Generation: ['generateContent', 'countTokens']
# Name: models/embedding-001 | Supported Generation: ['embedContent']
# Name: models/text-embedding-004 | Supported Generation: ['embedContent']
# Name: models/gemini-embedding-exp-03-07 | Supported Generation: ['embedContent', 'countTextTokens', 'countTokens']
# Name: models/gemini-embedding-exp | Supported Generation: ['embedContent', 'countTextTokens', 'countTokens']
# Name: models/gemini-embedding-001 | Supported Generation: ['embedContent', 'countTextTokens', 'countTokens', 'asyncBatchEmbedContent']
# Name: models/aqa | Supported Generation: ['generateAnswer']
# Name: models/imagen-3.0-generate-002 | Supported Generation: ['predict']
# Name: models/imagen-4.0-generate-preview-06-06 | Supported Generation: ['predict']
# Name: models/imagen-4.0-ultra-generate-preview-06-06 | Supported Generation: ['predict']
# Name: models/imagen-4.0-generate-001 | Supported Generation: ['predict']
# Name: models/imagen-4.0-ultra-generate-001 | Supported Generation: ['predict']
# Name: models/imagen-4.0-fast-generate-001 | Supported Generation: ['predict']
# Name: models/veo-2.0-generate-001 | Supported Generation: ['predictLongRunning']
# Name: models/veo-3.0-generate-preview | Supported Generation: ['predictLongRunning']
# Name: models/veo-3.0-fast-generate-preview | Supported Generation: ['predictLongRunning']
# Name: models/veo-3.0-generate-001 | Supported Generation: ['predictLongRunning']
# Name: models/veo-3.0-fast-generate-001 | Supported Generation: ['predictLongRunning']
# Name: models/gemini-2.5-flash-preview-native-audio-dialog | Supported Generation: ['countTokens', 'bidiGenerateContent']
# Name: models/gemini-2.5-flash-exp-native-audio-thinking-dialog | Supported Generation: ['countTokens', 'bidiGenerateContent']
# Name: models/gemini-2.0-flash-live-001 | Supported Generation: ['bidiGenerateContent', 'countTokens']
# Name: models/gemini-live-2.5-flash-preview | Supported Generation: ['bidiGenerateContent', 'countTokens']
# Name: models/gemini-2.5-flash-live-preview | Supported Generation: ['bidiGenerateContent', 'countTokens']
# Name: models/gemini-2.5-flash-native-audio-latest | Supported Generation: ['countTokens', 'bidiGenerateContent']
# Name: models/gemini-2.5-flash-native-audio-preview-09-2025 | Supported Generation: ['countTokens', 'bidiGenerateContent']
